# %% [markdown]
# # NPZ ROC analysis with fixed threshold 0.5
#
# This notebook reads saved `.npz` prediction files, plots seed-wise ROC curves with a min--max band and mean ROC curve, and reports final Accuracy/F1 using fixed threshold `T=0.5`.
#
# No threshold is selected from LOSO test predictions. Figures are displayed only and are not saved.

# %%
# ============================================================
# Notebook directory
# ============================================================
import os

os.chdir("/notebooks")
print("Current directory:",os.getcwd())
# Out:
# Current directory: /notebooks

# %%
# ============================================================
# Imports and settings
# ============================================================
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pathlib import Path
from sklearn.metrics import roc_curve,auc,accuracy_score,f1_score,confusion_matrix

EXPERIMENT      = "SIMPLE"
FIXED_THRESHOLD = 0.5

# Added EDA+PPG so that MoEVAE results are read, plotted, and exported.
MODALITIES = ["EDA","PPG","TEXT","EDA+PPG"]
TASKS      = ["AROUSAL","VALENCE","STIMULUS-LABEL"]

OUTPUT_DIR = Path("output")
TABLE_DIR  = OUTPUT_DIR/"tables_fixed_threshold"
TABLE_DIR.mkdir(parents=True,exist_ok=True)

MEAN_FPR = np.linspace(0,1,101)

TASK_DISPLAY = {
    "AROUSAL":r"$\mathtt{arousal\_category}$",
    "VALENCE":r"$\mathtt{valence\_category}$",
    "STIMULUS-LABEL":r"$\mathtt{stimulus}$-$\mathtt{label}$",
}

TASK_TABLE_NAME = {
    "AROUSAL":r"\texttt{arousal\_category}",
    "VALENCE":r"\texttt{valence\_category}",
    "STIMULUS-LABEL":r"\texttt{stimulus-label}",
}

MODEL_ORDER_BY_MODALITY = {
    "EDA":["MLP-Classifier","VAE-Classifier"],
    "PPG":["MLP-Classifier","VAE-Classifier"],
    "TEXT":["(DISTILLBERT+Proj128) MLP-Classifier","(DISTILLBERT+Proj128) VAE-Classifier"],
    "EDA+PPG":["MoEVAE-Classifier"],
}

# %%
# ============================================================
# Helper functions: file parsing and NPZ reading
# ============================================================
def normalize_model_name(model_name,modality=None):
    model_name = str(model_name).strip()
    modality   = str(modality).strip().upper() if modality is not None else None

    model_key = model_name.upper().replace("_","-").replace(" ","")

    if model_key in ["MLP","MLPCLASSIFIER","MLP-CLASSIFIER"]:
        return "MLP-Classifier"

    if model_key in ["DISTILLBERT+PROJ128","DISTILBERT+PROJ128","DISTILLBERT-PROJ128"]:
        return "(DISTILLBERT+Proj128) MLP-Classifier"

    if model_key in ["VAE","VAECLASSIFIER","VAE-CLASSIFIER"]:
        if modality=="TEXT":
            return "(DISTILLBERT+Proj128) VAE-Classifier"
        return "VAE-Classifier"

    if model_key in ["MOEVAE","MOE-VAE","MOEVAECLASSIFIER","MOEVAE-CLASSIFIER","MOE-VAE-CLASSIFIER"]:
        if modality=="TEXT":
            return "(DISTILLBERT+Proj128) MoEVAE-Classifier"
        return "MoEVAE-Classifier"

    return model_name


def normalize_task_name(task_name):
    task_name = str(task_name).strip()
    task_key  = task_name.upper().replace("_","-")

    if "AROUSAL" in task_key:
        return "AROUSAL"
    if "VALENCE" in task_key:
        return "VALENCE"
    if "STIMULUS" in task_key or "TASKWISE" in task_key:
        return "STIMULUS-LABEL"

    return task_name


def normalize_modality_name(modality):
    modality = str(modality).strip().upper().replace("_","+")

    pair_aliases = {
        "EDA+PPG":"EDA+PPG",
        "PPG+EDA":"EDA+PPG",
        "EDA+TEXT":"EDA+TEXT",
        "TEXT+EDA":"EDA+TEXT",
        "PPG+TEXT":"PPG+TEXT",
        "TEXT+PPG":"PPG+TEXT",
    }

    return pair_aliases.get(modality,modality)


def parse_prediction_file(file_name):
    base = Path(file_name).name
    base = base.replace("-loso_predictions.npz","")
    base = base.replace("_loso_predictions.npz","")
    base = base.replace(".npz","")

    parts = base.split("-")

    raw_model = parts[0]

    if parts[-1].upper() in ["SIMPLE","SMOTE"]:
        experiment = parts[-1].upper()
        body_parts = parts[1:-1]
    else:
        experiment = "SIMPLE"
        body_parts = parts[1:]

    if len(body_parts)==0:
        raise ValueError(f"Cannot parse modality/task from file name: {file_name}")

    # Supports both MoEVAE-EDA+PPG-AROUSAL-SIMPLE.npz and MoEVAE-EDA-PPG-AROUSAL-SIMPLE.npz
    first = body_parts[0].upper().replace("_","+")
    second = body_parts[1].upper().replace("_","+") if len(body_parts)>1 else ""

    if first in ["EDA+PPG","PPG+EDA","EDA+TEXT","TEXT+EDA","PPG+TEXT","TEXT+PPG"]:
        modality = normalize_modality_name(first)
        task_parts = body_parts[1:]
    elif first in ["EDA","PPG","TEXT"] and second in ["EDA","PPG","TEXT"]:
        modality = normalize_modality_name(first+"+"+second)
        task_parts = body_parts[2:]
    else:
        modality = normalize_modality_name(first)
        task_parts = body_parts[1:]

    task  = normalize_task_name("-".join(task_parts))
    model = normalize_model_name(raw_model,modality=modality)

    return {"raw_model":raw_model,"model":model,"modality":modality,"task":task,"experiment":experiment}


def repeat_or_values(data,key,n,default=np.nan):
    if key not in data.files:
        return np.repeat(default,n)

    values = data[key]

    if np.ndim(values)==0:
        return np.repeat(values.item(),n)
    if len(values)==1 and n>1:
        return np.repeat(values[0],n)

    return values


def get_gt(data):
    if "gt_class" in data.files:
        gt = data["gt_class"]
    elif "gt" in data.files:
        gt = data["gt"]
    elif "y_true" in data.files:
        gt = data["y_true"]
    else:
        raise KeyError("No ground-truth key found. Expected one of: gt_class, gt, y_true")

    gt = np.asarray(gt)

    if gt.ndim==2 and gt.shape[1]>1:
        gt = np.argmax(gt,axis=1)
    elif gt.ndim==2 and gt.shape[1]==1:
        gt = gt[:,0]

    return gt.astype(int).reshape(-1)


def get_pred_proba(data):
    if "pred_proba" in data.files:
        pred_proba = data["pred_proba"]
    elif "pred_probs" in data.files:
        pred_proba = data["pred_probs"]
    elif "y_proba" in data.files:
        pred_proba = data["y_proba"]
    elif "probs" in data.files:
        pred_proba = data["probs"]
    elif "probability" in data.files:
        pred_proba = data["probability"]
    elif "prob_vector" in data.files:
        pred_proba = data["prob_vector"]
    else:
        raise KeyError("No probability key found. Expected pred_proba/pred_probs/y_proba/probs/probability/prob_vector")

    pred_proba = np.asarray(pred_proba)

    if pred_proba.ndim==2 and pred_proba.shape[1]>=2:
        pred_proba = pred_proba[:,1]
    elif pred_proba.ndim==2 and pred_proba.shape[1]==1:
        pred_proba = pred_proba[:,0]

    return pred_proba.astype(float).reshape(-1)


def clean_sample_id(x):
    x = str(x)
    if x.endswith(".0"):
        x = x[:-2]
    return x

# %%
# ============================================================
# Helper functions: ROC and fixed-threshold metrics
# ============================================================
def get_seedwise_df(df_exp):
    df_exp = df_exp.copy()

    df_exp["gt"]         = df_exp["gt"].astype(int)
    df_exp["pred_proba"] = df_exp["pred_proba"].astype(float)
    df_exp["seed"]       = df_exp["seed"].astype(int)

    df_exp = df_exp.groupby(["seed","sample_id"],as_index=False).agg(
        gt=("gt","first"),
        pred_proba=("pred_proba","mean"),
    )

    return df_exp


def get_seed_roc(y_true,y_score):
    fpr_raw,tpr_raw,thresholds_raw = roc_curve(y_true,y_score)
    seed_auc = auc(fpr_raw,tpr_raw)

    roc_df = pd.DataFrame({"fpr":fpr_raw,"tpr":tpr_raw})
    roc_df = roc_df.sort_values(["fpr","tpr"],ascending=[True,False]).drop_duplicates("fpr",keep="first").sort_values("fpr")

    fpr = roc_df["fpr"].values
    tpr = roc_df["tpr"].values

    interp_tpr     = np.interp(MEAN_FPR,fpr,tpr)
    interp_tpr[0]  = 0.0
    interp_tpr[-1] = 1.0

    return fpr_raw,tpr_raw,thresholds_raw,interp_tpr,seed_auc


def fixed_threshold_tpr_fpr(y_true,y_score,threshold=0.5):
    y_pred = (y_score>=threshold).astype(int)
    tn,fp,fn,tp = confusion_matrix(y_true,y_pred,labels=[0,1]).ravel()

    tpr = tp/(tp+fn) if (tp+fn)>0 else np.nan
    fpr = fp/(fp+tn) if (fp+tn)>0 else np.nan

    return tpr,fpr


def compute_mean_roc_fixed_threshold(df_exp,threshold=0.5):
    df_exp = get_seedwise_df(df_exp)

    seed_roc_rows    = []
    seed_metric_rows = []

    interp_tprs = []
    seed_aucs   = []
    fixed_tprs  = []
    fixed_fprs  = []

    for seed,seed_df in df_exp.groupby("seed"):
        y_true  = seed_df["gt"].values
        y_score = seed_df["pred_proba"].values

        if len(np.unique(y_true))<2:
            continue

        fpr,tpr,thresholds,interp_tpr,seed_auc = get_seed_roc(y_true,y_score)

        interp_tprs.append(interp_tpr)
        seed_aucs.append(seed_auc)

        y_pred = (y_score>=threshold).astype(int)
        fixed_tpr,fixed_fpr = fixed_threshold_tpr_fpr(y_true,y_score,threshold=threshold)

        fixed_tprs.append(fixed_tpr)
        fixed_fprs.append(fixed_fpr)

        seed_roc_rows.append({"seed":seed,"fpr":fpr,"tpr":tpr,"thresholds":thresholds,"auc":seed_auc})
        seed_metric_rows.append({
            "seed":seed,
            "threshold":threshold,
            "accuracy":accuracy_score(y_true,y_pred),
            "f1":f1_score(y_true,y_pred,zero_division=0),
            "fixed_tpr":fixed_tpr,
            "fixed_fpr":fixed_fpr,
        })

    if len(interp_tprs)==0:
        return None

    interp_tprs = np.asarray(interp_tprs)

    return {
        "seed_roc_rows":seed_roc_rows,
        "seed_metric_rows":seed_metric_rows,
        "mean_fpr":MEAN_FPR,
        "mean_tpr":np.mean(interp_tprs,axis=0),
        "min_tpr":np.min(interp_tprs,axis=0),
        "max_tpr":np.max(interp_tprs,axis=0),
        "threshold":threshold,
        "fixed_tpr":np.nanmean(fixed_tprs),
        "fixed_fpr":np.nanmean(fixed_fprs),
        "mean_auc":np.mean(seed_aucs),
        "std_auc":np.std(seed_aucs),
    }


def format_mean_std(mean_value,std_value):
    if pd.isna(mean_value):
        return "-"
    if pd.isna(std_value):
        std_value = 0.0
    return f"{mean_value:.3f} ± {std_value:.3f}"

# %%
def dataframe_to_latex(df,path,caption="",label=""):
    import pandas as pd
    import re
    from pathlib import Path

    TASK_ORDER = ["AROUSAL","VALENCE","STIMULUS-LABEL"]

    TASK_ALIAS = {
        "AROUSAL":["AROUSAL","arousal_category",r"\texttt{arousal\_category}",r"$\mathtt{arousal\_category}$"],
        "VALENCE":["VALENCE","valence_category",r"\texttt{valence\_category}",r"$\mathtt{valence\_category}$"],
        "STIMULUS-LABEL":["STIMULUS-LABEL","stimulus-label",r"\texttt{stimulus-label}",r"$\mathtt{stimulus}$-$\mathtt{label}$"],
    }

    # Use the global modality/model order so MoEVAE is included in the exported result table.
    MODALITY_ORDER = list(MODALITIES)

    MODALITY_COLOR = {
        "EDA":"EDABlue",
        "PPG":"PPGGreen",
        "TEXT":"TEXTOrange",
        "EDA+PPG":"gray!20",
        "EDA+TEXT":"gray!20",
        "PPG+TEXT":"gray!20",
    }

    def latex_escape(x):
        if pd.isna(x):
            return ""
        x = str(x)
        if "\\" in x or "$" in x:
            return x
        x = x.replace("&","\\&")
        x = x.replace("%","\\%")
        x = x.replace("_","\\_")
        x = x.replace("#","\\#")
        x = x.replace("±","$\\pm$")
        return x

    def find_col(row,col_names):
        for col_name in col_names:
            if col_name in row.index:
                return col_name
        return None

    def format_mean_std(mean_value,std_value):
        if pd.isna(mean_value):
            return "-"
        if pd.isna(std_value):
            std_value = 0.0
        return f"{float(mean_value):.3f} ± {float(std_value):.3f}"

    def extract_float(x):
        if pd.isna(x):
            return None
        x = str(x)
        x = x.replace("$\\pm$","±")
        x = x.replace("\\pm","±")
        match = re.search(r"[-+]?\d*\.\d+|[-+]?\d+",x)
        if match is None:
            return None
        return float(match.group(0))

    def get_metric_text(row,metric_name):
        mean_col = find_col(row,[f"{metric_name}_mean",f"{metric_name.lower()}_mean"])
        std_col  = find_col(row,[f"{metric_name}_std",f"{metric_name.lower()}_std"])

        if mean_col is not None and std_col is not None:
            return format_mean_std(row[mean_col],row[std_col])

        value_col = find_col(row,[metric_name,metric_name.lower()])

        if value_col is not None:
            value = row[value_col]
            if isinstance(value,(float,int)):
                return f"{float(value):.3f}"
            return value

        return "-"

    def get_metric_value(row,metric_name):
        mean_col = find_col(row,[f"{metric_name}_mean",f"{metric_name.lower()}_mean"])

        if mean_col is not None:
            return float(row[mean_col])

        value_col = find_col(row,[metric_name,metric_name.lower()])

        if value_col is not None:
            return extract_float(row[value_col])

        return None

    def bold_if_best(text,value,best_value):
        text = latex_escape(text)

        if value is None or best_value is None:
            return text

        if abs(value-best_value)<1e-12:
            return r"\textbf{" + text + "}"

        return text

    path = Path(path)
    path.parent.mkdir(parents=True,exist_ok=True)

    df = df.copy()
    grouped_rows = []

    for modality in MODALITY_ORDER:
        df_modality = df[df["Modality"].eq(modality)].copy()

        if len(df_modality)==0:
            continue

        model_order = MODEL_ORDER_BY_MODALITY.get(modality,list(df_modality["Model"].drop_duplicates()))

        for model_name in model_order:
            df_model = df_modality[df_modality["Model"].eq(model_name)].copy()

            if len(df_model)==0:
                continue

            row_out = {
                "Modality":modality,
                "Model":model_name,
            }

            for task in TASK_ORDER:
                if "Target" in df_model.columns:
                    df_task = df_model[df_model["Target"].astype(str).isin(TASK_ALIAS[task])].copy()
                elif "task" in df_model.columns:
                    df_task = df_model[df_model["task"].eq(task)].copy()
                else:
                    df_task = pd.DataFrame()

                if len(df_task)==0:
                    row_out[f"{task}_Accuracy"]       = "-"
                    row_out[f"{task}_F1"]             = "-"
                    row_out[f"{task}_Accuracy_value"] = None
                    row_out[f"{task}_F1_value"]       = None
                    continue

                task_row = df_task.iloc[0]

                row_out[f"{task}_Accuracy"]       = get_metric_text(task_row,"Accuracy")
                row_out[f"{task}_F1"]             = get_metric_text(task_row,"F1")
                row_out[f"{task}_Accuracy_value"] = get_metric_value(task_row,"Accuracy")
                row_out[f"{task}_F1_value"]       = get_metric_value(task_row,"F1")

            grouped_rows.append(row_out)

    grouped_df = pd.DataFrame(grouped_rows)

    best_scores = {}

    for modality in MODALITY_ORDER:
        df_mod = grouped_df[grouped_df["Modality"].eq(modality)].copy()

        for task in TASK_ORDER:
            acc_values = [
                v for v in df_mod[f"{task}_Accuracy_value"].values
                if v is not None and pd.notna(v)
            ]

            f1_values = [
                v for v in df_mod[f"{task}_F1_value"].values
                if v is not None and pd.notna(v)
            ]

            best_scores[(modality,task,"Accuracy")] = max(acc_values) if len(acc_values)>0 else None
            best_scores[(modality,task,"F1")]       = max(f1_values) if len(f1_values)>0 else None

    grouped_df["row_best"] = False

    for idx,row in grouped_df.iterrows():
        modality = row["Modality"]
        is_best_row = False

        for task in TASK_ORDER:
            acc_value = row[f"{task}_Accuracy_value"]
            f1_value  = row[f"{task}_F1_value"]

            best_acc = best_scores[(modality,task,"Accuracy")]
            best_f1  = best_scores[(modality,task,"F1")]

            if acc_value is not None and best_acc is not None and abs(acc_value-best_acc)<1e-12:
                is_best_row = True

            if f1_value is not None and best_f1 is not None and abs(f1_value-best_f1)<1e-12:
                is_best_row = True

        grouped_df.loc[idx,"row_best"] = is_best_row

    with open(path,"w",encoding="utf-8") as f:
        f.write("\\begin{table}[H]\n")
        f.write("\\centering\n")
        f.write("\\scriptsize\n")
        f.write("\\setlength{\\tabcolsep}{4pt}\n")

        if caption!="":
            f.write(f"\\caption{{{caption}}}\n")
        if label!="":
            f.write(f"\\label{{{label}}}\n")

        col_format = "l"+("cc"*len(TASK_ORDER))
        f.write(f"\\begin{{tabular}}{{{col_format}}}\n")
        f.write("\\hline\n")

        header_1 = ["\\textbf{Model}"]

        for task in TASK_ORDER:
            header_1.append(f"\\multicolumn{{2}}{{c}}{{\\textbf{{{TASK_TABLE_NAME[task]}}}}}")

        f.write(" & ".join(header_1)+" \\\\\n")

        start_col = 2
        clines = []

        for _ in TASK_ORDER:
            end_col = start_col+1
            clines.append(f"\\cline{{{start_col}-{end_col}}}")
            start_col = end_col+1

        f.write("".join(clines)+"\n")

        header_2 = [""]

        for _ in TASK_ORDER:
            header_2.extend(["\\textbf{Accuracy}","\\textbf{F1}"])

        f.write(" & ".join(header_2)+" \\\\\n")
        f.write("\\hline\n")

        for modality_i,modality in enumerate(MODALITY_ORDER):
            df_mod = grouped_df[grouped_df["Modality"].eq(modality)].copy()

            if len(df_mod)==0:
                continue

            color_name = MODALITY_COLOR.get(modality,"gray!20")
            n_cols = 1+(2*len(TASK_ORDER))

            f.write(f"\\rowcolor{{{color_name}}}\\multicolumn{{{n_cols}}}{{l}}{{\\textbf{{{latex_escape(modality)}}}}} \\\\\n")

            for _,row in df_mod.iterrows():
                model_text = latex_escape(row["Model"])

                if row["row_best"]:
                    model_text = r"\textbf{" + model_text + "}"

                values = [model_text]

                for task in TASK_ORDER:
                    acc_text  = row[f"{task}_Accuracy"]
                    f1_text   = row[f"{task}_F1"]
                    acc_value = row[f"{task}_Accuracy_value"]
                    f1_value  = row[f"{task}_F1_value"]

                    best_acc = best_scores[(modality,task,"Accuracy")]
                    best_f1  = best_scores[(modality,task,"F1")]

                    values.extend([
                        bold_if_best(acc_text,acc_value,best_acc),
                        bold_if_best(f1_text,f1_value,best_f1),
                    ])

                f.write(" & ".join(values)+" \\\\\n")

            if modality_i<len(MODALITY_ORDER)-1:
                f.write("\\hline\n")

        f.write("\\hline\n")
        f.write("\\end{tabular}\n")
        f.write("\\end{table}\n")

    display_cols = ["Modality","Model"]

    for task in TASK_ORDER:
        display_cols.extend([
            f"{task}_Accuracy",
            f"{task}_F1",
        ])

    grouped_display_df = grouped_df[display_cols].copy()

    print("Saved LaTeX table:",path)

    return grouped_display_df

# %%
# ============================================================
# Read all NPZ prediction files
# ============================================================
npz_files = sorted(glob.glob("output/*.npz"))

print("Number of npz files found:",len(npz_files))

if len(npz_files)==0:
    raise FileNotFoundError("No .npz files found in output/*.npz")

all_rows = []

for file_path in npz_files:
    file_name  = Path(file_path).name
    data       = np.load(file_path,allow_pickle=True)
    gt         = get_gt(data)
    pred_proba = get_pred_proba(data)
    n          = len(gt)

    if len(pred_proba)!=n:
        raise ValueError(f"Length mismatch in {file_name}: len(gt)={n}, len(pred_proba)={len(pred_proba)}")

    meta = parse_prediction_file(file_name)

    sample_id = repeat_or_values(data,"sample_id",n,default="")
    sample_id = np.array([clean_sample_id(x) for x in sample_id])

    if np.all(sample_id==""):
        sample_id = np.array([f"{file_name}_{i}" for i in range(n)])

    row_df = pd.DataFrame({
        "file":np.repeat(file_name,n),
        "raw_model":np.repeat(meta["raw_model"],n),
        "model":np.repeat(meta["model"],n),
        "modality":np.repeat(meta["modality"],n),
        "task":np.repeat(meta["task"],n),
        "experiment":np.repeat(meta["experiment"],n),
        "sample_id":sample_id,
        "gt":gt,
        "pred_proba":pred_proba,
        "seed":repeat_or_values(data,"seed",n),
        "fold":repeat_or_values(data,"fold",n),
        "pid":repeat_or_values(data,"pid",n),
    })

    all_rows.append(row_df)

pred_df = pd.concat(all_rows,ignore_index=True)

print("Available files before filtering:")
display(pred_df[["file","raw_model","model","modality","task","experiment"]].drop_duplicates().sort_values(["modality","task","model"]))

pred_df = pred_df[
    pred_df["experiment"].eq(EXPERIMENT)
    & pred_df["modality"].isin(MODALITIES)
    & pred_df["task"].isin(TASKS)
].copy()

# keep only models included in plotting/table order
valid_models = []
for model_list in MODEL_ORDER_BY_MODALITY.values():
    valid_models.extend(model_list)
valid_models = sorted(set(valid_models))

pred_df = pred_df[pred_df["model"].isin(valid_models)].copy()

print("Prediction dataframe after filtering:")
display(pred_df.head())

print("Available files after filtering:")
display(pred_df[["file","raw_model","model","modality","task","experiment"]].drop_duplicates().sort_values(["modality","task","model"]))
# Out:
# Number of npz files found: 27
# Prediction dataframe:
#                                                 file            raw_model  \
# 0  DISTILLBERT+Proj128-TEXT-AROUSAL-SIMPLE-predic...  DISTILLBERT+Proj128
# 1  DISTILLBERT+Proj128-TEXT-AROUSAL-SIMPLE-predic...  DISTILLBERT+Proj128
# 2  DISTILLBERT+Proj128-TEXT-AROUSAL-SIMPLE-predic...  DISTILLBERT+Proj128
# 3  DISTILLBERT+Proj128-TEXT-AROUSAL-SIMPLE-predic...  DISTILLBERT+Proj128
# 4  DISTILLBERT+Proj128-TEXT-AROUSAL-SIMPLE-predic...  DISTILLBERT+Proj128
#
#                                   model modality     task experiment  \
# 0  (DISTILLBERT+Proj128) MLP-Classifier     TEXT  AROUSAL     SIMPLE
# 1  (DISTILLBERT+Proj128) MLP-Classifier     TEXT  AROUSAL     SIMPLE
# 2  (DISTILLBERT+Proj128) MLP-Classifier     TEXT  AROUSAL     SIMPLE
# 3  (DISTILLBERT+Proj128) MLP-Classifier     TEXT  AROUSAL     SIMPLE
# 4  (DISTILLBERT+Proj128) MLP-Classifier     TEXT  AROUSAL     SIMPLE
#
#   sample_id  gt  pred_proba  seed  fold                    pid
# 0       5_1   0    0.425032    42     1  5,8,16,20,28,29,33,39
# 1       5_2   0    0.036479    42     1  5,8,16,20,28,29,33,39
# 2       5_3   0    0.003461    42     1  5,8,16,20,28,29,33,39
# 3       5_4   0    0.212653    42     1  5,8,16,20,28,29,33,39
# 4       5_5   0    0.619799    42     1  5,8,16,20,28,29,33,39
# Available files after filtering:
#                                                     file            raw_model  \
# 2880              MLP-EDA-AROUSAL-SIMPLE-predictions.npz                  MLP
# 17298             VAE-EDA-AROUSAL-SIMPLE-predictions.npz                  VAE
# 3879       MLP-EDA-STIMULUS-LABEL-SIMPLE-predictions.npz                  MLP
# 18297      VAE-EDA-STIMULUS-LABEL-SIMPLE-predictions.npz                  VAE
# 4878              MLP-EDA-VALENCE-SIMPLE-predictions.npz                  MLP
# 19296             VAE-EDA-VALENCE-SIMPLE-predictions.npz                  VAE
# 5877              MLP-PPG-AROUSAL-SIMPLE-predictions.npz                  MLP
# 20295             VAE-PPG-AROUSAL-SIMPLE-predictions.npz                  VAE
# 6876       MLP-PPG-STIMULUS-LABEL-SIMPLE-predictions.npz                  MLP
# 21294      VAE-PPG-STIMULUS-LABEL-SIMPLE-predictions.npz                  VAE
# 7875              MLP-PPG-VALENCE-SIMPLE-predictions.npz                  MLP
# 22293             VAE-PPG-VALENCE-SIMPLE-predictions.npz                  VAE
# 0      DISTILLBERT+Proj128-TEXT-AROUSAL-SIMPLE-predic...  DISTILLBERT+Proj128
# 23292            VAE-TEXT-AROUSAL-SIMPLE-predictions.npz                  VAE
# 960    DISTILLBERT+Proj128-TEXT-STIMULUS-LABEL-SIMPLE...  DISTILLBERT+Proj128
# 24252     VAE-TEXT-STIMULUS-LABEL-SIMPLE-predictions.npz                  VAE
# 1920   DISTILLBERT+Proj128-TEXT-VALENCE-SIMPLE-predic...  DISTILLBERT+Proj128
# 25212            VAE-TEXT-VALENCE-SIMPLE-predictions.npz                  VAE
#
#                                       model modality            task  \
# 2880                         MLP-Classifier      EDA         AROUSAL
# 17298                        VAE-Classifier      EDA         AROUSAL
# 3879                         MLP-Classifier      EDA  STIMULUS-LABEL
# 18297                        VAE-Classifier      EDA  STIMULUS-LABEL
# 4878                         MLP-Classifier      EDA         VALENCE
# 19296                        VAE-Classifier      EDA         VALENCE
# 5877                         MLP-Classifier      PPG         AROUSAL
# 20295                        VAE-Classifier      PPG         AROUSAL
# 6876                         MLP-Classifier      PPG  STIMULUS-LABEL
# 21294                        VAE-Classifier      PPG  STIMULUS-LABEL
# 7875                         MLP-Classifier      PPG         VALENCE
# 22293                        VAE-Classifier      PPG         VALENCE
# 0      (DISTILLBERT+Proj128) MLP-Classifier     TEXT         AROUSAL
# 23292  (DISTILLBERT+Proj128) VAE-Classifier     TEXT         AROUSAL
# 960    (DISTILLBERT+Proj128) MLP-Classifier     TEXT  STIMULUS-LABEL
# 24252  (DISTILLBERT+Proj128) VAE-Classifier     TEXT  STIMULUS-LABEL
# 1920   (DISTILLBERT+Proj128) MLP-Classifier     TEXT         VALENCE
# 25212  (DISTILLBERT+Proj128) VAE-Classifier     TEXT         VALENCE
#
#       experiment
# 2880      SIMPLE
# 17298     SIMPLE
# 3879      SIMPLE
# 18297     SIMPLE
# 4878      SIMPLE
# 19296     SIMPLE
# 5877      SIMPLE
# 20295     SIMPLE
# 6876      SIMPLE
# 21294     SIMPLE
# 7875      SIMPLE
# 22293     SIMPLE
# 0         SIMPLE
# 23292     SIMPLE
# 960       SIMPLE
# 24252     SIMPLE
# 1920      SIMPLE
# 25212     SIMPLE

# %%
# ============================================================
# Run analysis and display ROC plots
# Fixed threshold 0.5 is used for Accuracy and F1.
# Figures are displayed only and are not saved.
# ============================================================
seed_results_rows = []
summary_rows      = []

for modality in MODALITIES:
    models_for_modality = MODEL_ORDER_BY_MODALITY[modality]

    fig,axes = plt.subplots(
        len(models_for_modality),
        len(TASKS),
        figsize=(18,4.5*len(models_for_modality)),
        sharex=True,
        sharey=True,
    )

    if len(models_for_modality)==1:
        axes = np.expand_dims(axes,axis=0)

    for row_i,model in enumerate(models_for_modality):
        for col_i,task in enumerate(TASKS):
            ax = axes[row_i,col_i]

            df_exp = pred_df[
                pred_df["modality"].eq(modality)
                & pred_df["model"].eq(model)
                & pred_df["task"].eq(task)
            ].copy()

            model_name = model
            task_name  = TASK_DISPLAY.get(task,task)

            if len(df_exp)==0:
                ax.text(0.5,0.5,"No data",ha="center",va="center",transform=ax.transAxes)
                ax.set_title(f"{modality}: {model_name} - {task_name}")
                ax.set_xlabel("False Positive Rate")
                ax.set_ylabel("True Positive Rate")
                ax.grid(alpha=0.30)
                continue

            result = compute_mean_roc_fixed_threshold(df_exp,threshold=FIXED_THRESHOLD)

            if result is None:
                ax.text(0.5,0.5,"ROC not defined",ha="center",va="center",transform=ax.transAxes)
                ax.set_title(f"{modality}: {model_name} - {task_name}")
                ax.set_xlabel("False Positive Rate")
                ax.set_ylabel("True Positive Rate")
                ax.grid(alpha=0.30)
                continue

            # ROC for each seed
            for seed_roc in result["seed_roc_rows"]:
                ax.plot(seed_roc["fpr"],seed_roc["tpr"],lw=1.1,alpha=0.65,label=f"Seed {seed_roc['seed']}")

            # min-max TPR band across seeds
            ax.fill_between(result["mean_fpr"],result["min_tpr"],result["max_tpr"],alpha=0.22,label="Seed min-max band")

            # mean ROC
            ax.plot(result["mean_fpr"],result["mean_tpr"],lw=2.4,color="black",label="Mean ROC")

            # random classifier
            ax.plot([0,1],[0,1],linestyle="--",lw=1.1,color="grey",label="Random")

            # show only AUC, no threshold text
            ax.text(
                0.96,0.05,
                f"AUC = {result['mean_auc']:.3f} ± {result['std_auc']:.3f}",
                transform=ax.transAxes,
                fontsize=10,
                ha="right",
                va="bottom",
                bbox=dict(boxstyle="round",facecolor="white",alpha=0.85),
            )

            ax.set_title(f"{modality}: {model_name} - {task_name}")
            ax.set_xlabel("False Positive Rate")
            ax.set_ylabel("True Positive Rate")
            ax.grid(alpha=0.30)

            # seed-wise metric rows using fixed threshold 0.5
            for seed_metric in result["seed_metric_rows"]:
                seed_auc = [x["auc"] for x in result["seed_roc_rows"] if x["seed"]==seed_metric["seed"]][0]

                seed_results_rows.append({
                    "modality":modality,
                    "model":model,
                    "model_name":model_name,
                    "task":task,
                    "target":TASK_TABLE_NAME.get(task,task),
                    "seed":seed_metric["seed"],
                    "threshold":FIXED_THRESHOLD,
                    "accuracy":seed_metric["accuracy"],
                    "f1":seed_metric["f1"],
                    "auc":seed_auc,
                    "fixed_tpr":seed_metric["fixed_tpr"],
                    "fixed_fpr":seed_metric["fixed_fpr"],
                })

            seed_metrics_df = pd.DataFrame(result["seed_metric_rows"])

            summary_rows.append({
                "Modality":modality,
                "Model":model_name,
                "Target":TASK_TABLE_NAME.get(task,task),
                "Threshold_value":FIXED_THRESHOLD,
                "Accuracy_mean":seed_metrics_df["accuracy"].mean(),
                "Accuracy_std":seed_metrics_df["accuracy"].std(ddof=0),
                "F1_mean":seed_metrics_df["f1"].mean(),
                "F1_std":seed_metrics_df["f1"].std(ddof=0),
                "AUC_mean":result["mean_auc"],
                "AUC_std":result["std_auc"],
                "TPR_mean":seed_metrics_df["fixed_tpr"].mean(),
                "TPR_std":seed_metrics_df["fixed_tpr"].std(ddof=0),
                "FPR_mean":seed_metrics_df["fixed_fpr"].mean(),
                "FPR_std":seed_metrics_df["fixed_fpr"].std(ddof=0),
            })

    handles,labels = [],[]

    for ax in axes.flatten():
        h,l = ax.get_legend_handles_labels()
        for handle,label in zip(h,l):
            if label not in labels:
                handles.append(handle)
                labels.append(label)

    fig.legend(handles,labels,loc="lower center",ncol=4,fontsize=10,frameon=True,bbox_to_anchor=(0.5,-0.02))
    plt.tight_layout(rect=[0,0.05,1,0.98])
    plt.show()

# %%
# ============================================================
# Build final results tables based on fixed threshold T=0.5
# ============================================================
seed_results_table = pd.DataFrame(seed_results_rows)
summary_raw_table  = pd.DataFrame(summary_rows)

summary_table = summary_raw_table.copy()
display(summary_table)

if "Threshold_value" not in summary_table.columns:
    summary_table["Threshold_value"] = FIXED_THRESHOLD

summary_table["Threshold"] = summary_table["Threshold_value"].map(lambda x:f"{float(x):.3f}")
summary_table["Accuracy"]  = summary_table.apply(lambda r:format_mean_std(r["Accuracy_mean"],r["Accuracy_std"]),axis=1)
summary_table["F1"]        = summary_table.apply(lambda r:format_mean_std(r["F1_mean"],r["F1_std"]),axis=1)
summary_table["AUC"]       = summary_table.apply(lambda r:format_mean_std(r["AUC_mean"],r["AUC_std"]),axis=1)

summary_table = summary_table[["Modality","Model","Target","Threshold","Accuracy","F1","AUC"]].copy()

wide_results_table = summary_table.pivot_table(
    index=["Modality","Model"],
    columns="Target",
    values=["Threshold","Accuracy","F1","AUC"],
    aggfunc="first",
)

wide_results_table.columns = [f"{metric}_{target}" for metric,target in wide_results_table.columns]
wide_results_table = wide_results_table.reset_index()

seed_results_path = TABLE_DIR/"npz_seedwise_results_fixed_threshold_0_5.csv"
summary_raw_path  = TABLE_DIR/"npz_summary_results_raw_fixed_threshold_0_5.csv"
summary_path      = TABLE_DIR/"npz_summary_results_fixed_threshold_0_5.csv"
wide_path         = TABLE_DIR/"npz_summary_results_wide_fixed_threshold_0_5.csv"
latex_path        = TABLE_DIR/"npz_summary_results_grouped_fixed_threshold_0_5.tex"

seed_results_table.to_csv(seed_results_path,index=False)
summary_raw_table.to_csv(summary_raw_path,index=False)
summary_table.to_csv(summary_path,index=False)
wide_results_table.to_csv(wide_path,index=False)

grouped_results_table = dataframe_to_latex(
    summary_table,
    latex_path,
    caption="Classification results using a fixed threshold of $T=0.5$ for each model and target label.",
    label="tab:results_grouped_fixed_threshold",
)

print("Saved tables:")
print(seed_results_path)
print(summary_raw_path)
print(summary_path)
print(wide_path)
print(latex_path)

print("\nSeed-wise results:")
display(seed_results_table)

print("\nFinal summary table:")
display(summary_table)

print("\nWide results table:")
display(wide_results_table)

print("\nGrouped LaTeX table preview:")
display(grouped_results_table)
# Out:
#    Modality                                 Model                      Target  \
# 0       EDA                        MLP-Classifier  \texttt{arousal\_category}
# 1       EDA                        MLP-Classifier  \texttt{valence\_category}
# 2       EDA                        MLP-Classifier     \texttt{stimulus-label}
# 3       EDA                        VAE-Classifier  \texttt{arousal\_category}
# 4       EDA                        VAE-Classifier  \texttt{valence\_category}
# 5       EDA                        VAE-Classifier     \texttt{stimulus-label}
# 6       PPG                        MLP-Classifier  \texttt{arousal\_category}
# 7       PPG                        MLP-Classifier  \texttt{valence\_category}
# 8       PPG                        MLP-Classifier     \texttt{stimulus-label}
# 9       PPG                        VAE-Classifier  \texttt{arousal\_category}
# 10      PPG                        VAE-Classifier  \texttt{valence\_category}
# 11      PPG                        VAE-Classifier     \texttt{stimulus-label}
# 12     TEXT  (DISTILLBERT+Proj128) MLP-Classifier  \texttt{arousal\_category}
# 13     TEXT  (DISTILLBERT+Proj128) MLP-Classifier  \texttt{valence\_category}
# 14     TEXT  (DISTILLBERT+Proj128) MLP-Classifier     \texttt{stimulus-label}
# 15     TEXT  (DISTILLBERT+Proj128) VAE-Classifier  \texttt{arousal\_category}
# 16     TEXT  (DISTILLBERT+Proj128) VAE-Classifier  \texttt{valence\_category}
# 17     TEXT  (DISTILLBERT+Proj128) VAE-Classifier     \texttt{stimulus-label}
#
#     Accuracy_mean  Accuracy_std   F1_mean    F1_std  AUC_mean   AUC_std  \
# 0        0.557558      0.010208  0.454662  0.029348  0.553913  0.016013
# 1        0.524525      0.011056  0.533797  0.012898  0.577293  0.013842
# 2        0.872873      0.001416  0.854163  0.002933  0.868615  0.005295
# 3        0.579580      0.012974  0.477588  0.000737  0.584929  0.008028
# 4        0.548549      0.007078  0.585693  0.008299  0.590746  0.011902
# 5        0.836837      0.007491  0.822296  0.006849  0.865924  0.002258
# 6        0.530531      0.009909  0.411574  0.010457  0.534193  0.020371
# 7        0.560561      0.007491  0.606117  0.011794  0.598871  0.018326
# 8        0.775776      0.019045  0.765607  0.011337  0.853458  0.002009
# 9        0.561562      0.014712  0.434143  0.001081  0.552952  0.012508
# 10       0.566567      0.014156  0.592758  0.008027  0.595508  0.024737
# 11       0.761762      0.008611  0.759671  0.004352  0.854979  0.004794
# 12       0.575810      0.034963  0.319346  0.054993  0.502644  0.025935
# 13       0.647955      0.025004  0.681297  0.028055  0.693243  0.027211
# 14       0.861111      0.019642  0.852437  0.024222  0.934220  0.010214
# 15       0.556906      0.016801  0.298551  0.011843  0.491332  0.037645
# 16       0.683256      0.021307  0.719989  0.027461  0.718912  0.009564
# 17       0.843943      0.021962  0.833029  0.027343  0.924146  0.019672
#
#     TPR_mean   TPR_std  FPR_mean   FPR_std
# 0   0.540936  0.053757  0.433790  0.019373
# 1   0.448845  0.012993  0.358779  0.010796
# 2   0.837838  0.011034  0.099099  0.006742
# 3   0.561404  0.018950  0.410959  0.029592
# 4   0.526403  0.019939  0.417303  0.041500
# 5   0.849099  0.003185  0.172973  0.013240
# 6   0.479532  0.010941  0.442922  0.009864
# 7   0.557756  0.018669  0.435115  0.012466
# 8   0.822072  0.022969  0.261261  0.051153
# 9   0.491228  0.014325  0.401826  0.029826
# 10  0.519802  0.004042  0.361323  0.036521
# 11  0.846847  0.011484  0.306306  0.024308
# 12  0.311128  0.064479  0.297158  0.052261
# 13  0.650059  0.029141  0.354432  0.032358
# 14  0.805556  0.039284  0.083333  0.000000
# 15  0.292736  0.016839  0.317053  0.034813
# 16  0.704726  0.037373  0.347043  0.005681
# 17  0.782793  0.050648  0.094907  0.027454
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Threshold_value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 10
#       7 summary_table = summary_raw_table.copy()
#       8 display(summary_table)
# ---> 10 summary_table["Threshold"] = summary_table["Threshold_value"].map(lambda x:f"{x:.3f}")
#      11 summary_table["Accuracy"]  = summary_table.apply(lambda r:format_mean_std(r["Accuracy_mean"],r["Accuracy_std"]),axis=1)
#      12 summary_table["F1"]        = summary_table.apply(lambda r:format_mean_std(r["F1_mean"],r["F1_std"]),axis=1)
#
# File /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'Threshold_value'

# %% [markdown]
# ## Interpretation note
#
# This notebook uses fixed threshold \(T=0.5\) for Accuracy and F1. No threshold is selected from LOSO test predictions, so the held-out participant is not used to tune the decision threshold.
#
# ROC-AUC is still reported because it is threshold-independent. The ROC plots show seed-wise ROC curves, the min--max TPR band across seeds, the mean ROC curve, and the operating point for \(T=0.5\).
